# %%
import os

# %%
os.getcwd()
# Out:
# '/home/ofirn/medMamba/MedMamba'

# %%
import pytorch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pytorch
#
# ModuleNotFoundError: No module named 'pytorch'
